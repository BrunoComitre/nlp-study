# %% [markdown]
# # Exercício 2
#
# ## Utilizando o exercício 1 da Lista de Exercícios 2, considere um arquivo de entrada no formato CSV (comma separated values) com informações relativas a acidentes na aviação civil brasileira nos últimos 10 anos (arquivo anv.csv)
#
# ### 1- Leia o arquivo em um DataFrame e a partir dele processe os dados identificando o total de ocorrencias no período avaliado e, baseado nessa informação, crie um arquivo de saída em formato JSON (statistics.json) com as seguintes as estatísticas (número de ocorrências e percentual do total) por fase de operação (coluna aeronave_fase_operacao)
#
# ### 2 - Crie um arquivo de saida (formato CSV, encoding UTF-8 e separador ;) com nome levels.csv contendo as seguintes informações:
# ```
# operation          -> aeronave_operador_categoria
# type               -> aeronave_tipo_veiculo
# manufacturer       -> aeronave_fabricante
# engine_type        -> aeronave_motor_tipo
# engines            -> aeronave_motor_quantidade
# year_manufacturing -> aeronave_ano_fabricacao
# seating            -> aeronave_assentos
# fatalities         -> total_fatalidades
# ```
#
# ### Considerando apenas acidentes cujo nível de dano da aeronave tenha sido  LEVE ou NENHUM (coluna aeronave_nivel_dano) E que o número de fatalidades (total_fatalidades) tenha sido superior à 0 (zero).

# %%
import numpy as np
import pandas as pd
from itertools import groupby 
import json

# %%
dataset = pd.read_csv('anv.csv', sep='~')
dataset
# Out:
#       codigo_ocorrencia aeronave_matricula aeronave_operador_categoria  \
# 0       201106142171203              PPGXE                   AEROCLUBE
# 1       200804256669287              PPGXE                   AEROCLUBE
# 2       201205209591320              PTRBN        OPERADOR DE AERONAVE
# 3       201012015549851              PTKUK        OPERADOR DE AERONAVE
# 4       201708190325167              PTKUK         OPERADOR PARTICULAR
# 5       201511054981552              PPGSZ                   AEROCLUBE
# 6       201803182255192              PPGSZ                   AEROCLUBE
# 7       201102219282454              PPGSZ                   AEROCLUBE
# 8       200811065510448              PTSLD        OPERADOR DE AERONAVE
# 9       200811166771745              PTSLD        OPERADOR DE AERONAVE
# 10      200803068583317              PPVLD        OPERADOR DE AERONAVE
# 11      200802196619791              PPVNX        OPERADOR DE AERONAVE
# ...

# %%
dataset['codigo_ocorrencia'].sum()
# Out:
# 1044208066768039204

# %%
dataset.skew()
# Out:
# codigo_ocorrencia           0.088330
# aeronave_pmd                4.544304
# aeronave_assentos           2.618482
# aeronave_ano_fabricacao    -5.718297
# total_fatalidades          11.219131
# dtype: float64

# %%
dataset = json.dumps([{'fase_operacao': k, 'ocorrencias': v, 'percentual': str(round(v * 100 / sum(data.values()), 3 )) + '%' } for k, v in data.items()], indent = 4, ensure_ascii = False)
output_file.write(fd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-5c5639b9dc13> in <module>()
# ----> 1 dataset = json.dumps([{'fase_operacao': k, 'ocorrencias': v, 'percentual': str(round(v * 100 / sum(data.values()), 3 )) + '%' } for k, v in data.items()], indent = 4, ensure_ascii = False)
#       2 output_file.write(fd)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'items'

# %%
names = dataset.columns.values.tolist()
data = dataset.values

# %%
#print json.dumps(nested_json2, indent=4)
with open('statistics.json', 'w') as outfile:
     outfile.write(json.dumps(dataset, indent=4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c92e6a474207> in <module>()
#       1 #print json.dumps(nested_json2, indent=4)
#       2 with open('statistics.json', 'w') as outfile:
# ----> 3      outfile.write(json.dumps(dataset, indent=4))
#
# ~\Anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~\Anaconda3\lib\json\encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# --> 201             chunks = list(chunks)
# ...

# %%
colunas=['aeronave_operador_categoria', 'aeronave_tipo_veiculo', 'aeronave_fabricante', 'aeronave_motor_tipo', 
         'aeronave_motor_quantidade', 'aeronave_ano_fabricacao' ,'aeronave_assentos', 'total_fatalidades']
dataset[colunas].head()
# Out:
#   aeronave_operador_categoria aeronave_tipo_veiculo  \
# 0                   AEROCLUBE                 AVIÃO
# 1                   AEROCLUBE                 AVIÃO
# 2        OPERADOR DE AERONAVE                 AVIÃO
# 3        OPERADOR DE AERONAVE                 AVIÃO
# 4         OPERADOR PARTICULAR                 AVIÃO
#
#            aeronave_fabricante aeronave_motor_tipo aeronave_motor_quantidade  \
# 0  NEIVA INDUSTRIA AERONAUTICA              PISTÃO                 MONOMOTOR
# 1  NEIVA INDUSTRIA AERONAUTICA              PISTÃO                 MONOMOTOR
# 2                      EMBRAER              PISTÃO                   BIMOTOR
# 3               TWIN COMMANDER              PISTÃO                   BIMOTOR
# 4               TWIN COMMANDER              PISTÃO                   BIMOTOR
#
#    aeronave_ano_fabricacao  aeronave_assentos  total_fatalidades
# 0                   1962.0                2.0                  0
# ...

# %%
dataset[colunas].to_excel('levels.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __new__(cls, path, engine, **kwargs)
#     846                     engine = config.get_option('io.excel.{ext}.writer'
# --> 847                                                .format(ext=ext))
#     848                     if engine == 'auto':
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in __call__(self, *args, **kwds)
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in _get_option(pat, silent)
#      96 def _get_option(pat, silent=False):
# ---> 97     key = _get_single_key(pat, silent)
#      98
#
# ~\Anaconda3\lib\site-packages\pandas\core\config.py in _get_single_key(pat, silent)
#      82             _warn_if_deprecated(pat)
# ...
